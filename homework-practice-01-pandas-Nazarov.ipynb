# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 25.09.2024
#
# Мягкий дедлайн: 23:59MSK 06.10.2024
#
# Жесткий дедлайн: 23:59MSK 10.10.2024

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов без учёта бонусов. Сдавать задание после жёсткого дедлайна нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате `homework-practice-01-pandas-Username.ipynb`, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: 10.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
n = 12345
n = str(n)
for c in n:
  print(c)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидите много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно

# %% [markdown]
# ### Kaggle
#
# Альтернативой является **Kaggle**, он же площадка для самых разных соревнований по машинному обучению
#
# Он, как и колаб, предоставляет бесплатный GPU, и даже не один, с чётким лимитом в 30 часов в неделю (colab может его внезапно отобрать, kaggle - нет) более мощные CPU с большим числом ядер, и больше Гб ОЗУ (раз так в 2.5)
#
# https://www.kaggle.com
#
# К сожалению мир не идеален, недостатки следующие:
# - необходимость загружать датасеты через специальную кнопочку
# - невозможность использовать свои скрипты и модули :(
# - нужно тыкать техподдержку, чтобы создать аккаунт из России

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в `pandas` — это `pd.DataFrame`, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и StackOverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> и всего, где можно применить лямбда-функции (`assign`, `map`, ...) крайне нежелательно

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите 3 последних строки.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
# your code
df = pd.read_excel('end_seminar.xlsx')
df.iloc[-3:]
# Out:
#                   timestamp                                id  rating  \
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 358       NaN    NaN  Сбор и обработка данных с помощью краудсорсинга
# 359       NaN    NaN                 Безопасность компьютерных систем
# 360       NaN    NaN                Анализ неструктурированных данных
#
#                                                 fall_2  \
# 358                        Statistical Learning Theory
# 359  Принятие решений в условиях риска и неопределё...
# 360                      Моделирование временных рядов
#
#                                 fall_3  \
# 358  Анализ неструктурированных данных
# 359  Анализ неструктурированных данных
# 360  Высокопроизводительные вычисления
#
# ...

# %% [markdown]
# ### Ответьте на вопросы:
# 1. Сколько было уникальных пользователей из групп 18-го года набора, а сколько из групп 17-го года?

# %%
# количество уникальных пользователей из групп 18-го года набора
df_18_unique_users = df[df['18_group'].notna()]
df_18_unique_users['id'].nunique()
# Out:
# 213

# %%
# количество уникальных пользователей из групп 17-го года набора
df_17_unique_users = df[df['17_group'].notna()]
df_17_unique_users['id'].nunique()
# Out:
# 134

# %% [markdown]
# 2. Есть ли уникальные студенты с равными перцентилями?

# %%
# your code
# если количество уникальных id хотя бы на 1 больше количества уникальных перцентилей, то точно найдутся 2 уникальных студента с равными перцентилями по принципу Дирихле
if df['id'].nunique() > df['percentile'].nunique():
  print('Есть')
else:
  print('Нет')
# Out:
# Есть

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
# your code
df.isna()
# Out:
#      timestamp     id  rating  18_group  is_mi  fall_1  fall_2  fall_3  \
# 0        False  False   False     False   True   False   False   False
# 1        False  False   False     False   True   False   False   False
# 2        False  False   False     False   True   False   False   False
# 3        False  False   False     False   True   False   False   False
# 4        False  False   False     False   True   False   False   False
# ..         ...    ...     ...       ...    ...     ...     ...     ...
# 356      False  False   False      True   True   False   False   False
# 357      False  False   False      True   True   False   False   False
# 358      False  False   False      True   True   False   False   False
# 359      False  False   False      True   True   False   False   False
# 360      False  False   False      True   True   False   False   False
#
#      spring_1  spring_2  spring_3  is_first_time  percentile  17_group  \
# ...

# %% [markdown]
# есть элементы датафрейма, равные True ⇒ в данных есть пропуски

# %%
def function(series):
  return series.shape[0] - series.count() # вычитаем из общего количества элементов в колонке количество элементов, не являющихся NaN

ser_nans = df.agg(function)
list(ser_nans.loc[ser_nans.iloc[:] > 0].index) # лист, в котором находятся колонки, в которых есть пропуски
# Out:
# ['18_group', 'is_mi', 'is_first_time', '17_group', 'blended', 'is_ml_student']

# %%
ser_nans.loc[ser_nans.iloc[:] > 0] # серия, в которой показано сколько пропусков в каждой из колонок, которая содержит пропуски
# Out:
# 18_group         138
# is_mi            343
# is_first_time      2
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок, нулём для числовых и False для булевых (постарайтесь избежать перечисления названий всех столбцов).

# %%
# your code
#NaN есть только в колонках 18_group, is_mi, is_first_time, 17_group, blended, is_ml_student
df[['is_mi', 'is_ml_student']] = df[['is_mi', 'is_ml_student']].fillna(False)
df[['is_mi', 'is_ml_student']] = df[['is_mi', 'is_ml_student']].astype(bool)
df.fillna(df.dtypes.replace({'float64': 0.0, 'object': ""}), inplace=True)

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Каково процентное соотношение ответов? Сколько из них "Нет"?

# %%
# your code
ser_is_first_time = df.groupby('is_first_time')['is_first_time'].count()
ser_is_first_time['Нет'] # количество ответов "Нет"
# Out:
# 51

# %%
round(ser_is_first_time['Нет'] / (ser_is_first_time['Нет'] + ser_is_first_time['Да']) * 100, 2) # процент числа ответов "Нет" от суммарного количества ответов "Да" и "Нет"
# Out:
# 14.21

# %%
round(ser_is_first_time['Да'] / (ser_is_first_time['Нет'] + ser_is_first_time['Да']) * 100, 2) # процент числа ответов "Да" от суммарного количества ответов "Да" и "Нет"
# Out:
# 85.79

# %% [markdown]
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
# your code
df.sort_values(by='timestamp',ascending=False, inplace=True)
df.drop_duplicates(subset=['id'], inplace=True)

# %% [markdown]
# #### 4. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
# your code
df_blended_1 = df.groupby('blended')['blended'].count()
df_blended_1.drop(labels='', inplace=True)
df_blended_1
# Out:
# blended
# DevOps                                   87
# Введение в дифференциальную геометрию    15
# Соревновательный анализ данных           32
# Name: blended, dtype: int64

# %%
list(df_blended_1.index) # такие blended-курсы существуют для четверокурсников
# Out:
# ['DevOps',
#  'Введение в дифференциальную геометрию',
#  'Соревновательный анализ данных']

# %%
df_blended_1.idxmax() # на этот blended-курс записалось наибольшее количество студентов
# Out:
# 'DevOps'

# %%
df_blended_2 = df.groupby('blended')['rating'].mean()
df_blended_2.drop(labels='', inplace=True)
df_blended_2
# Out:
# blended
# DevOps                                   1154.172414
# Введение в дифференциальную геометрию    1210.733333
# Соревновательный анализ данных           1144.218750
# Name: rating, dtype: float64

# %%
df_blended_2.idxmax() # на этом blended-курсе собрались студенты с самым высоким средним рейтингом
# Out:
# 'Введение в дифференциальную геометрию'

# %%
df_blended_1[df_blended_2.idxmax()] # количество студентов на курсе, на котором собрались студенты с самым высоким средним рейтингом
# Out:
# 15

# %% [markdown]
# #### 5. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
# your code
df_same_sets = df.groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'], as_index=False).count()
df_same_sets.drop(df_same_sets.loc[:, 'id':], inplace=True, axis=1)
df_same_sets.rename(columns = {'timestamp' : 'count'}, inplace=True)
df_same_sets = df_same_sets[df_same_sets['count'] != 1]
df_same_sets
# Out:
#                                               fall_1  \
# 0                        Statistical Learning Theory
# 60             Байесовские методы машинного обучения
# 62             Байесовские методы машинного обучения
# 72                  Безопасность компьютерных систем
# 84                  Безопасность компьютерных систем
# 102                 Безопасность компьютерных систем
# 105                 Безопасность компьютерных систем
# 113                 Безопасность компьютерных систем
# 137                 Безопасность компьютерных систем
# 155                 Безопасность компьютерных систем
# 184                Высокопроизводительные вычисления
# 201                Высокопроизводительные вычисления
# 244                    Моделирование временных рядов
# 292  Сбор и обработка данных с помощью краудсорсинга
# 313                                         Язык SQL
#
#                                               fall_2  \
# 0                  Анализ неструктурированных данных
# ...

# %% [markdown]
# #### 6. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
# курсы по выбору, на которые записывались студенты 18-го года набора
df_18_group = df[df['18_group'] != 0.0]
ser_18_group = pd.concat([df_18_group.groupby('fall_1')['id'].count(), df_18_group.groupby('fall_2')['id'].count(), df_18_group.groupby('fall_3')['id'].count(), df_18_group.groupby('spring_1')['id'].count(), df_18_group.groupby('spring_2')['id'].count(), df_18_group.groupby('spring_3')['id'].count()], axis=1).sum(axis=1)
# курсы по выбору, на которые записывались студенты 17-го года набора
df_17_group = df[df['17_group'] != 0.0]
ser_17_group = pd.concat([df_17_group.groupby('fall_1')['id'].count(), df_17_group.groupby('fall_2')['id'].count(), df_17_group.groupby('fall_3')['id'].count(), df_17_group.groupby('spring_1')['id'].count(), df_17_group.groupby('spring_2')['id'].count(), df_17_group.groupby('spring_3')['id'].count()], axis=1).sum(axis=1)
df_both_groups = pd.concat([ser_17_group, ser_18_group], axis=1)
list(df_both_groups[(~df_both_groups.iloc[:, 0].isna()) & (~df_both_groups.iloc[:, 1].isna())].index) # курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года
# Out:
# ['Statistical Learning Theory',
#  'Безопасность компьютерных систем',
#  'Высокопроизводительные вычисления',
#  'Моделирование временных рядов',
#  'Принятие решений в условиях риска и неопределённости',
#  'Сбор и обработка данных с помощью краудсорсинга',
#  'Численные методы']

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
list(df_both_groups[(df_both_groups.iloc[:, 0].isna()) & (~df_both_groups.iloc[:, 1].isna())].index) # курсы, на которые записывались только студентам 18-го года
# Out:
# ['Матричные вычисления',
#  'Теория баз данных',
#  'Язык SQL',
#  'Анализ данных в бизнесе',
#  'Дискретная оптимизация',
#  'Дополнительные главы прикладной статистики',
#  'Компьютерные сети',
#  'Машинное обучение 2',
#  'Промышленное программирование на языке Java',
#  'Системы баз данных']

# %%
list(df_both_groups[(~df_both_groups.iloc[:, 0].isna()) & (df_both_groups.iloc[:, 1].isna())].index) # курсы, на которые записывались только студентам 17-го года
# Out:
# ['Анализ неструктурированных данных',
#  'Байесовские методы машинного обучения',
#  'Глубинное обучение в обработке звука',
#  'Генеративные модели в машинном обучении',
#  'Компьютерное зрение',
#  'Конфликты и кооперация',
#  'Методы сжатия и передачи медиаданных',
#  'Обучение с подкреплением',
#  'Проектирование и разработка высоконагруженных сервисов',
#  'Символьные вычисления']

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# your code
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 7. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
# your code
df['day'] = df['timestamp'].dt.day
df_dates = df.groupby('day')['rating'].mean()
x = df_dates.index
y = df_dates
plt.bar(x, y)
plt.xlabel('Дни получения ответов')
plt.ylabel('Средний рейтинг')
plt.title('График средних рейтингов по дням получения ответов')
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# your code
plt.savefig('graph.pdf')

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# <span style="color:red">!!!ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ!!!</span>.
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# ## 📌 **Алгоритм распределения студентов по курсам**:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# ## ☝️ **Обращаем ваше внимание на следующие детали:**
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь `df.to_csv('solution.csv', index=None)`
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
# (￣^￣)ゞ
# если 18 года, то 2 - если True в is_mi/is_ml_student, иначе - 1
# если 17 года, то 2 - если в 17_group - 171/172/173, иначе - 1
df.loc[df['18_group'] != 0, 'num_fall_courses'] = 1
df.loc[(df['18_group'] != 0) & (df['is_mi'] == True), 'num_fall_courses'] = 2
df.loc[df['17_group'] != 0, 'num_fall_courses'] = 1
df.loc[df['17_group'].isin([171.0, 172.0, 173.0]), 'num_fall_courses'] = 2

# %% [markdown]
# Проверка:

# %%
col_name = 'num_fall_courses'

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %% [markdown]
# Здесь и далее код написан частями, но если закомментировать последние строки вывода и объединить части, то получиться цельный код. Я оставлю код, написанный частями, для наглядности и понятности полученных результатов.

# %%
# (￣^￣)ゞ
ser_fall_1_1_wave = df.groupby('fall_1')['id'].count()
ser_fall_2_1_wave = df[(df['num_fall_courses'] == 2.0) & (df['fall_2'] != df['fall_1'])].groupby('fall_2')['id'].count()
ser_fall_1_wave = pd.concat([ser_fall_1_1_wave, ser_fall_2_1_wave], axis=1)
ser_fall_1_wave = ser_fall_1_wave.sum(axis=1)
ser_fall_1_wave # серия, в которой показано, у какого количества студентов каждый курс указан первым приоритетом
# Out:
# Statistical Learning Theory                              33
# Анализ неструктурированных данных                        48
# Байесовские методы машинного обучения                    24
# Безопасность компьютерных систем                        115
# Высокопроизводительные вычисления                        44
# Глубинное обучение в обработке звука                     23
# Матричные вычисления                                     15
# Моделирование временных рядов                            31
# Принятие решений в условиях риска и неопределённости      8
# Сбор и обработка данных с помощью краудсорсинга          50
# Теория баз данных                                        14
# Язык SQL                                                 29
# dtype: int64

# %%
df.sort_values(by='percentile', inplace=True)
df.loc[:, 'course1'] = '-'
df.loc[:, 'course2'] = '-'
all_fall_courses_1_wave = list(ser_fall_1_wave.index)
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
# определим курсы (good_courses), на которые желающих меньше, чем максимальное количество мест, и запишем потом всех желающих попасть на них сразу в первую волну
big_special_course = 'Анализ неструктурированных данных'
special_courses = ['Statistical Learning Theory', 'Высокопроизводительные вычисления']
good_courses = []
for course in all_fall_courses_1_wave:
  if course == big_special_course:
    good_courses.append(course)
  elif course in special_courses:
    if ser_fall_1_wave[course] <= 60:
      good_courses.append(course)
  else:
    if ser_fall_1_wave[course] <= 30:
      good_courses.append(course)
good_courses
# Out:
# ['Statistical Learning Theory',
#  'Анализ неструктурированных данных',
#  'Байесовские методы машинного обучения',
#  'Высокопроизводительные вычисления',
#  'Глубинное обучение в обработке звука',
#  'Матричные вычисления',
#  'Принятие решений в условиях риска и неопределённости',
#  'Теория баз данных',
#  'Язык SQL']

# %%
for item in all_fall_courses_1_wave:
  if item in good_courses:
    df.loc[(df['fall_1'] == item) & (df['course1'] == '-') & (df['num_fall_courses'] == 1.0), 'course1'] = item
    df.loc[((df['fall_1'] == item) | (df['fall_2'] == item)) & (df['num_fall_courses'] == 2.0) & (df['course1'] == '-'), 'course1'] = item
    df.loc[((df['fall_1'] == item) | (df['fall_2'] == item)) & (df['num_fall_courses'] == 2.0) & (df['course1'] != '-') & (df['course1'] != item) & (df['course2'] == '-'), 'course2'] = item
  else:
    if item in special_courses:
      massive = list(df.loc[(df['fall_1'] == item) | ((df['fall_2'] == item) & (df['num_fall_courses'] == 2.0) & (df['fall_2'] != df['fall_1']))].index)
      count = 0
      for i in range(len(massive)):
        if count < 60:
          if df.loc[massive[i], 'course1'] == '-':
            df.loc[massive[i], 'course1'] = item
            count += 1
          elif df.loc[massive[i], 'course1'] != item and df.loc[massive[i], 'course2'] == '-' and df.loc[massive[i], 'num_fall_courses'] == 2.0:
            df.loc[massive[i], 'course2'] = item
            count += 1
        else:
          break
    else:
      massive = list(df.loc[(df['fall_1'] == item) | ((df['fall_2'] == item) & (df['num_fall_courses'] == 2.0) & (df['fall_2'] != df['fall_1']))].index)
      count = 0
      for i in range(len(massive)):
        if count < 30:
          if df.loc[massive[i], 'course1'] == '-':
            df.loc[massive[i], 'course1'] = item
            count += 1
          elif df.loc[massive[i], 'course1'] != item and df.loc[massive[i], 'course2'] == '-' and df.loc[massive[i], 'num_fall_courses'] == 2.0:
            df.loc[massive[i], 'course2'] = item
            count += 1
        else:
          break
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
df['is_first_place'] = np.nan
df['is_last_place'] = np.nan
for item in all_fall_courses_1_wave:
  df.loc[df[(df['course1'] == item) | (df['course2'] == item)].idxmin(skipna=True)['percentile'], 'is_first_place'] = True
for item in all_fall_courses_1_wave:
  df.loc[df[(df['course1'] == item) | (df['course2'] == item)].idxmax(skipna=True)['percentile'], 'is_last_place'] = True
df
# Out:
# <ipython-input-174-fab087eabaff>:4: FutureWarning: The behavior of DataFrame.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df.loc[df[(df['course1'] == item) | (df['course2'] == item)].idxmin(skipna=True)['percentile'], 'is_first_place'] = True
# <ipython-input-174-fab087eabaff>:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df[(df['course1'] == item) | (df['course2'] == item)].idxmin(skipna=True)['percentile'], 'is_first_place'] = True
# <ipython-input-174-fab087eabaff>:4: FutureWarning: The behavior of DataFrame.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
# ...

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name = 'is_first_place'      # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'     # insert name of your new column with is_last_place as str


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# #### 3. [2 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
# (￣^￣)ゞ
ser_1_wave_1_course_total = df.groupby('course1')['id'].count()
ser_1_wave_2_course_total = df.groupby('course2')['id'].count()
ser_1_wave_total = pd.concat([ser_1_wave_1_course_total, ser_1_wave_2_course_total], axis=1)
ser_1_wave_total = ser_1_wave_total.sum(axis=1)
ser_1_wave_total.drop(labels=['-'], inplace=True)
ser_1_wave_total_enrolled = ser_1_wave_total.copy()
ser_1_wave_total_enrolled # серия, которая показывает, сколько студентов на какой курс уже зачислены
# Out:
# Statistical Learning Theory                             33.0
# Анализ неструктурированных данных                       48.0
# Байесовские методы машинного обучения                   24.0
# Безопасность компьютерных систем                        30.0
# Высокопроизводительные вычисления                       44.0
# Глубинное обучение в обработке звука                    23.0
# Матричные вычисления                                    15.0
# Моделирование временных рядов                           30.0
# Принятие решений в условиях риска и неопределённости     8.0
# Сбор и обработка данных с помощью краудсорсинга         30.0
# Теория баз данных                                       14.0
# Язык SQL                                                29.0
# dtype: float64

# %%
for item in all_fall_courses_1_wave:
  if item == big_special_course:
    ser_1_wave_total[item] = 100000
  elif item in special_courses:
    ser_1_wave_total[item] = 60 - ser_1_wave_total[item]
  else:
    ser_1_wave_total[item] = 30 - ser_1_wave_total[item]
ser_1_wave_total # показывает, сколько мест на курсах 1 волны осталось после 1 волны
# Out:
# Statistical Learning Theory                                 27.0
# Анализ неструктурированных данных                       100000.0
# Байесовские методы машинного обучения                        6.0
# Безопасность компьютерных систем                             0.0
# Высокопроизводительные вычисления                           16.0
# Глубинное обучение в обработке звука                         7.0
# Матричные вычисления                                        15.0
# Моделирование временных рядов                                0.0
# Принятие решений в условиях риска и неопределённости        22.0
# Сбор и обработка данных с помощью краудсорсинга              0.0
# Теория баз данных                                           16.0
# Язык SQL                                                     1.0
# dtype: float64

# %%
df_2f = df[(df['course1'] == '-') | ((df['num_fall_courses'] == 2.0) & (df['course2'] == '-'))]
df_2f.loc[:, 'num_courses_already_enrolled'] = 0
df_2f.loc[df_2f['course1'] != '-', 'num_courses_already_enrolled'] = 1
df_2f
# Out:
# <ipython-input-179-873f136e407d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2f.loc[:, 'num_courses_already_enrolled'] = 0
#                   timestamp                                id  rating  \
# 75  2020-05-18 16:45:06.205  081eba3952cfc116e0e9b941d6a974a2     692
# 102 2020-05-18 19:16:43.914  d08d06bc5d31e35616fafc59de6f2e34     691
# 82  2020-05-18 17:16:57.130  86eebda725013685effcb0c97591132e     690
# 83  2020-05-18 17:21:14.354  7f9d0f835bf734ccd4619041c3475c1c     689
# 104 2020-05-18 19:23:38.274  76d70b75a12f7b2ae593d02da6ed62ec     688
# ..                      ...                               ...     ...
# 293 2020-05-18 18:22:26.260  f2e1cfc27a724879ac2a8c98004c14b0     981
# ...

# %%
# проведём 2 волну, в ней будут участвовать из fall_2 с num_fall_courses = 1.0 и из fall_3 с num_fall_courses = 2.0
ser_fall_2_2_wave = df_2f[df_2f['num_fall_courses'] == 1.0].groupby('fall_2')['id'].count()
ser_fall_3_2_wave = df_2f[(df_2f['num_fall_courses'] == 2.0) & (df_2f['fall_3'] != df_2f['fall_2'])].groupby('fall_3')['id'].count()
ser_fall_2_wave = pd.concat([ser_fall_2_2_wave, ser_fall_3_2_wave], axis=1)
ser_fall_2_wave = ser_fall_2_wave.sum(axis=1)
ser_fall_2_wave # серия, в которой показано, у какого количества студентов каждый курс указан вторым приоритетом
# Out:
# Statistical Learning Theory                              8.0
# Безопасность компьютерных систем                         4.0
# Высокопроизводительные вычисления                       25.0
# Глубинное обучение в обработке звука                     7.0
# Матричные вычисления                                     9.0
# Моделирование временных рядов                           10.0
# Принятие решений в условиях риска и неопределённости     1.0
# Сбор и обработка данных с помощью краудсорсинга         15.0
# Теория баз данных                                        4.0
# Язык SQL                                                14.0
# Анализ неструктурированных данных                        5.0
# Байесовские методы машинного обучения                    1.0
# dtype: float64

# %%
all_fall_courses_2_wave = list(ser_fall_2_wave.index)
# определим курсы (good_courses2), на которые желающих меньше, чем максимальное количество мест, и запишем потом всех желающих попасть на них сразу во вторую волну
good_courses2 = []
for course in all_fall_courses_2_wave:
  if course in all_fall_courses_1_wave:
    if course == big_special_course:
      good_courses2.append(course)
    else:
      if ser_fall_2_wave[course] <= ser_1_wave_total[course]:
        good_courses2.append(course)
  else:
    if course == big_special_course:
      good_courses2.append(course)
    elif course in special_courses:
      if ser_fall_2_wave[course] <= 60:
        good_courses2.append(course)
    else:
      if ser_fall_2_wave[course] <= 30:
        good_courses2.append(course)
good_courses2
# Out:
# ['Statistical Learning Theory',
#  'Глубинное обучение в обработке звука',
#  'Матричные вычисления',
#  'Принятие решений в условиях риска и неопределённости',
#  'Теория баз данных',
#  'Анализ неструктурированных данных',
#  'Байесовские методы машинного обучения']

# %%
for item in all_fall_courses_2_wave:
  if item in all_fall_courses_1_wave:
    if item in good_courses2:
      df_2f.loc[(df_2f['fall_2'] == item) & (df_2f['course1'] == '-') & (df_2f['num_fall_courses'] == 1.0), 'course1'] = item
      df_2f.loc[(df_2f['fall_3'] == item) & (df_2f['num_fall_courses'] == 2.0) & (df_2f['course1'] == '-'), 'course1'] = item
      df_2f.loc[(df_2f['fall_3'] == item) & (df_2f['num_fall_courses'] == 2.0) & (df_2f['course1'] != '-') & (df_2f['course1'] != item) & (df_2f['course2'] == '-'), 'course2'] = item
    else:
      massive = list(df_2f.loc[((df_2f['fall_2'] == item) & (df_2f['num_fall_courses'] == 1.0)) | ((df_2f['fall_3'] == item) & (df_2f['num_fall_courses'] == 2.0))].index)
      count = 0
      for i in range(len(massive)):
        if count < ser_1_wave_total[item]:
          if df_2f.loc[massive[i], 'course1'] == '-':
            df_2f.loc[massive[i], 'course1'] = item
            count += 1
          elif df_2f.loc[massive[i], 'course1'] != item and df_2f.loc[massive[i], 'course2'] == '-' and df_2f.loc[massive[i], 'num_fall_courses'] == 2.0:
            df_2f.loc[massive[i], 'course2'] = item
            count += 1
        else:
          break
  else:
    if item in good_courses2:
      df_2f.loc[(df_2f['fall_2'] == item) & (df_2f['course1'] == '-') & (df_2f['num_fall_courses'] == 1.0), 'course1'] = item
      df_2f.loc[(df_2f['fall_3'] == item) & (df_2f['num_fall_courses'] == 2.0) & (df_2f['course1'] == '-'), 'course1'] = item
      df_2f.loc[(df_2f['fall_3'] == item) & (df_2f['num_fall_courses'] == 2.0) & (df_2f['course1'] != '-') & (df_2f['course1'] != item) & (df_2f['course2'] == '-'), 'course2'] = item
    else:
      if item in special_courses:
        massive = list(df_2f.loc[((df_2f['fall_2'] == item) & (df_2f['num_fall_courses'] == 1.0)) | ((df_2f['fall_3'] == item) & (df_2f['num_fall_courses'] == 2.0))].index)
        count = 0
        for i in range(len(massive)):
          if count < 60:
            if df_2f.loc[massive[i], 'course1'] == '-':
              df_2f.loc[massive[i], 'course1'] = item
              count += 1
            elif df_2f.loc[massive[i], 'course1'] != item and df_2f.loc[massive[i], 'course2'] == '-' and df_2f.loc[massive[i], 'num_fall_courses'] == 2.0:
              df_2f.loc[massive[i], 'course2'] = item
              count += 1
          else:
            break
      else:
        massive = list(df_2f.loc[((df_2f['fall_2'] == item) & (df_2f['num_fall_courses'] == 1.0)) | ((df_2f['fall_3'] == item) & (df_2f['num_fall_courses'] == 2.0))].index)
        count = 0
        for i in range(len(massive)):
          if count < 30:
            if df_2f.loc[massive[i], 'course1'] == '-':
              df_2f.loc[massive[i], 'course1'] = item
              count += 1
            elif df_2f.loc[massive[i], 'course1'] != item and df_2f.loc[massive[i], 'course2'] == '-' and df_2f.loc[massive[i], 'num_fall_courses'] == 2.0:
              df_2f.loc[massive[i], 'course2'] = item
              count += 1
          else:
            break
df_2f
# Out:
#                   timestamp                                id  rating  \
# 75  2020-05-18 16:45:06.205  081eba3952cfc116e0e9b941d6a974a2     692
# 102 2020-05-18 19:16:43.914  d08d06bc5d31e35616fafc59de6f2e34     691
# 82  2020-05-18 17:16:57.130  86eebda725013685effcb0c97591132e     690
# 83  2020-05-18 17:21:14.354  7f9d0f835bf734ccd4619041c3475c1c     689
# 104 2020-05-18 19:23:38.274  76d70b75a12f7b2ae593d02da6ed62ec     688
# ..                      ...                               ...     ...
# 293 2020-05-18 18:22:26.260  f2e1cfc27a724879ac2a8c98004c14b0     981
# 110 2020-05-18 19:36:51.479  f5d9f99cb876ca0888d18b6e444fa1b1     516
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
ser_2_wave_1_course_total = df_2f[df_2f['num_courses_already_enrolled'] == 0].groupby('course1')['id'].count()

ser_2_wave_2_course_total = df_2f[df_2f['num_courses_already_enrolled'] == 1].groupby('course2')['id'].count()
ser_2_wave_total = pd.concat([ser_2_wave_1_course_total, ser_2_wave_2_course_total], axis=1)
ser_2_wave_total = ser_2_wave_total.sum(axis=1)

ser_2_wave_total = pd.concat([ser_1_wave_total_enrolled, ser_2_wave_total], axis=1)

ser_2_wave_total = ser_2_wave_total.sum(axis=1)
ser_2_wave_total.drop(labels=['-'], inplace=True)
ser_2_wave_total_enrolled = ser_2_wave_total.copy()
ser_2_wave_total_enrolled # серия, которая показывает, сколько студентов на какой курс уже зачислены суммарно в 1 и во 2 волну
# Out:
# Statistical Learning Theory                             41.0
# Анализ неструктурированных данных                       53.0
# Байесовские методы машинного обучения                   25.0
# Безопасность компьютерных систем                        30.0
# Высокопроизводительные вычисления                       60.0
# Глубинное обучение в обработке звука                    30.0
# Матричные вычисления                                    24.0
# Моделирование временных рядов                           30.0
# Принятие решений в условиях риска и неопределённости     9.0
# Сбор и обработка данных с помощью краудсорсинга         30.0
# Теория баз данных                                       18.0
# Язык SQL                                                30.0
# dtype: float64

# %%
for item in all_fall_courses_1_wave:
  if item in all_fall_courses_2_wave:
    if item == big_special_course:
      ser_2_wave_total[item] = 100000
    elif item in special_courses:
      ser_2_wave_total[item] = 60 - ser_2_wave_total[item]
    else:
      ser_2_wave_total[item] = 30 - ser_2_wave_total[item]
  else:
    if item == big_special_course:
      ser_2_wave_total[item] = 100000
    elif item in special_courses:
      ser_2_wave_total[item] = 60 - ser_2_wave_total[item]
    else:
      ser_2_wave_total[item] = 30 - ser_2_wave_total[item]
ser_2_wave_total # показывает, сколько мест на курсах 2 волны осталось после 2 волны
# Out:
# Statistical Learning Theory                                 19.0
# Анализ неструктурированных данных                       100000.0
# Байесовские методы машинного обучения                        5.0
# Безопасность компьютерных систем                             0.0
# Высокопроизводительные вычисления                            0.0
# Глубинное обучение в обработке звука                         0.0
# Матричные вычисления                                         6.0
# Моделирование временных рядов                                0.0
# Принятие решений в условиях риска и неопределённости        21.0
# Сбор и обработка данных с помощью краудсорсинга              0.0
# Теория баз данных                                           12.0
# Язык SQL                                                     0.0
# dtype: float64

# %%
# перенесём записи в df
for ind in list(df_2f.index):
  df.loc[ind, 'course1'] = df_2f.loc[ind, 'course1']
  df.loc[ind, 'course2'] = df_2f.loc[ind, 'course2']
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
# проведём 3 волну, в ней будут участвовать из fall_3 с num_fall_courses = 1.0
df_3f = df[(df['course1'] == '-') & (df['num_fall_courses'] == 1.0)]
ser_fall_3_wave = df_3f.groupby('fall_3')['id'].count()
ser_fall_3_wave # серия, в которой показано, у какого количества студентов каждый курс указан третьим приоритетом
# Out:
# fall_3
# Statistical Learning Theory                              2
# Анализ неструктурированных данных                        3
# Высокопроизводительные вычисления                        4
# Матричные вычисления                                    10
# Моделирование временных рядов                            2
# Принятие решений в условиях риска и неопределённости     1
# Сбор и обработка данных с помощью краудсорсинга          6
# Теория баз данных                                        6
# Язык SQL                                                 8
# Name: id, dtype: int64

# %%
all_fall_courses_3_wave = list(ser_fall_3_wave.index)
# определим курсы (good_courses3), на которые желающих меньше, чем максимальное количество мест, и запишем потом всех желающих попасть на них сразу в третью волну
good_courses3 = []
for course in all_fall_courses_3_wave:
  if course in all_fall_courses_2_wave:
    if course == big_special_course:
      good_courses3.append(course)
    else:
      if ser_fall_3_wave[course] <= ser_2_wave_total[course]:
        good_courses3.append(course)
  elif course in all_fall_courses_1_wave:
    if course == big_special_course:
      good_courses3.append(course)
    else:
      if ser_fall_3_wave[course] <= ser_1_wave_total[course]:
        good_courses3.append(course)
  else:
    if course == big_special_course:
      good_courses3.append(course)
    elif course in special_courses:
      if ser_fall_3_wave[course] <= 60:
        good_courses3.append(course)
    else:
      if ser_fall_3_wave[course] <= 30:
        good_courses3.append(course)
good_courses3
# Out:
# ['Statistical Learning Theory',
#  'Анализ неструктурированных данных',
#  'Принятие решений в условиях риска и неопределённости',
#  'Теория баз данных']

# %%
for item in all_fall_courses_3_wave:
  if item in all_fall_courses_2_wave:
    if item in good_courses3:
      df_3f.loc[(df_3f['fall_3'] == item) & (df_3f['course1'] == '-'), 'course1'] = item
    else:
      massive = list(df_3f.loc[(df_3f['fall_3'] == item) & (df_3f['course1'] == '-')].index)
      count = 0
      for i in range(len(massive)):
        if count < ser_2_wave_total[item]:
          df_3f.loc[massive[i], 'course1'] = item
          count += 1
        else:
          break
  elif item in all_fall_courses_1_wave:
    if item in good_courses3:
      df_3f.loc[(df_3f['fall_3'] == item) & (df_3f['course1'] == '-'), 'course1'] = item
    else:
      massive = list(df_3f.loc[(df_3f['fall_3'] == item) & (df_3f['course1'] == '-')].index)
      count = 0
      for i in range(len(massive)):
        if count < ser_1_wave_total[item]:
          df_3f.loc[massive[i], 'course1'] = item
          count += 1
        else:
          break
  else:
    if item in good_courses3:
      df_3f.loc[(df_3f['fall_3'] == item) & (df_3f['course1'] == '-'), 'course1'] = item
    else:
      if item in special_courses:
        massive = list(df_3f.loc[(df_3f['fall_3'] == item) & (df_3f['course1'] == '-')].index)
        count = 0
        for i in range(len(massive)):
          if count < 60:
            if df_3f.loc[massive[i], 'course1'] == '-':
              df_3f.loc[massive[i], 'course1'] = item
              count += 1
          else:
            break
      else:
        massive = list(df_3f.loc[(df_3f['fall_3'] == item) & (df_3f['course1'] == '-')].index)
        count = 0
        for i in range(len(massive)):
          if count < 30:
            if df_3f.loc[massive[i], 'course1'] == '-':
              df_3f.loc[massive[i], 'course1'] = item
              count += 1
          else:
            break
df_3f
# Out:
#                   timestamp                                id  rating  \
# 104 2020-05-18 19:23:38.274  76d70b75a12f7b2ae593d02da6ed62ec     688
# 153 2020-05-18 21:53:48.048  cabc5ea85cac3029dc2aecc4955f9cf3     686
# 47  2020-05-17 14:04:41.159  34f75b81eb7b1cc9e9e4ef5bfd7fa69a     678
# 20  2020-05-15 21:55:16.699  f0f6f3881894172a0f04e79b554b49e6     673
# 189 2020-05-18 23:30:27.005  7bf79897c5645954846e2e03ec803887     653
# 339 2020-05-18 23:10:45.547  07b6ce7fd93bde95ce5fe14a5131a960    1160
# 173 2020-05-18 22:36:17.913  227347077a7d1d0544ddf5643b97cf8c     633
# 98  2020-05-18 18:53:41.094  5ee2ad618729a6dc3bdb7f2858826ef0     628
# 118 2020-05-18 20:26:39.021  2b0d7dd550bcca4c586cbb27d8478aa8     619
# 208 2020-05-19 00:09:12.146  efc406545c2b0e958ec89b4c1e4f7a28     615
# 50  2020-05-17 17:40:31.867  323f162a5cad5f11e84bf294dd73197e     605
# 133 2020-05-18 21:15:58.617  a6ce02b12540bca3cdd15757f8a2e919     597
# ...

# %%
ser_3_wave_total = df_3f.groupby('course1')['id'].count()
ser_3_wave_total.drop(labels=['-'], inplace=True)

ser_3_wave_total = pd.concat([ser_2_wave_total_enrolled, ser_3_wave_total], axis=1)

ser_3_wave_total = ser_3_wave_total.sum(axis=1)
ser_3_wave_total_enrolled = ser_3_wave_total.copy()
ser_3_wave_total_enrolled # серия, которая показывает, сколько студентов на какой курс зачислены после всех трёх волн
# Out:
# Statistical Learning Theory                             43.0
# Анализ неструктурированных данных                       56.0
# Байесовские методы машинного обучения                   25.0
# Безопасность компьютерных систем                        30.0
# Высокопроизводительные вычисления                       60.0
# Глубинное обучение в обработке звука                    30.0
# Матричные вычисления                                    30.0
# Моделирование временных рядов                           30.0
# Принятие решений в условиях риска и неопределённости    10.0
# Сбор и обработка данных с помощью краудсорсинга         30.0
# Теория баз данных                                       24.0
# Язык SQL                                                30.0
# dtype: float64

# %%
# перенесём записи 3 волны в df
for ind in list(df_3f.index):
  df.loc[ind, 'course1'] = df_3f.loc[ind, 'course1']
  df.loc[ind, 'course2'] = df_3f.loc[ind, 'course2']
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
df.loc[(df['num_fall_courses'] == 1.0) & (df['course1'] == '-'), 'course1'] = '???'
df.loc[(df['num_fall_courses'] == 2.0) & (df['course1'] == '-'), 'course1'] = '???'
df.loc[(df['num_fall_courses'] == 2.0) & (df['course2'] == '-'), 'course2'] = '???'
df_res_fall = df[['id', 'course1', 'course2']]
df_res_fall = df_res_fall.rename(columns={'id' : 'ID'})
df_res_fall
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1  \
# 80                    Безопасность компьютерных систем
# 231                        Statistical Learning Theory
# 91                                Матричные вычисления
# 273                  Высокопроизводительные вычисления
# 19     Сбор и обработка данных с помощью краудсорсинга
# ..                                                 ...
# 359  Принятие решений в условиях риска и неопределё...
# ...

# %%
df_res_fall.to_csv('res_fall.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# никнейм: nsnazarov@edu.hse.ru
#
# ссылка на успешную посылку: https://contest.yandex.ru/contest/68637/run-report/120310264/
#
# ID успешной посылки: 120310264

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# ### 4. [1 балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
# (￣^'￣)ゞ
# добавим вместо колонки num_fall_corses колонку num_spring_courses
df = df.rename(columns={'num_fall_courses' : 'num_spring_courses'})
df.loc[df['18_group'] != 0, 'num_spring_courses'] = 1
df.loc[df['17_group'] != 0, 'num_spring_courses'] = 1
df.loc[df['17_group'].isin([171.0, 172.0, 173.0]), 'num_spring_courses'] = 2
df.drop(labels=['is_first_place', 'is_last_place'], axis=1, inplace=True)
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
# сдвинем приоритеты МОПовцев, которые в качестве spring_1/spring_2/spring_3 указали 'Машинное обучение 2'
ml_spring_1 = list(df[((df['is_ml_student'] == True) | (df['17_group'] == 171.0) | (df['17_group'] == 172.0)) & (df['spring_1'] == 'Машинное обучение 2') & (df['spring_2'] != 'Машинное обучение 2') & (df['spring_3'] != 'Машинное обучение 2')].index)
for ind in ml_spring_1:
  df.loc[ind, 'spring_1'] = df.loc[ind, 'spring_2']
  df.loc[ind, 'spring_2'] = df.loc[ind, 'spring_3']
  df.loc[ind, 'spring_3'] = '-'
ml_spring_2 = list(df[((df['is_ml_student'] == True) | (df['17_group'] == 171.0) | (df['17_group'] == 172.0)) & (df['spring_1'] != 'Машинное обучение 2') & (df['spring_2'] == 'Машинное обучение 2') & (df['spring_3'] != 'Машинное обучение 2')].index)
for ind in ml_spring_2:
  df.loc[ind, 'spring_2'] = df.loc[ind, 'spring_3']
  df.loc[ind, 'spring_3'] = '-'
ml_spring_3 = list(df[((df['is_ml_student'] == True) | (df['17_group'] == 171.0) | (df['17_group'] == 172.0)) & (df['spring_1'] != 'Машинное обучение 2') & (df['spring_2'] != 'Машинное обучение 2') & (df['spring_3'] == 'Машинное обучение 2')].index)
for ind in ml_spring_3:
  df.loc[ind, 'spring_3'] = '-'
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
df.loc[:, 'course1'] = '-'
df.loc[:, 'course2'] = '-'
ser_spring_1_1_wave = df.groupby('spring_1')['id'].count()
ser_spring_2_1_wave = df[(df['num_spring_courses'] == 2.0) & (df['spring_2'] != df['spring_1'])].groupby('spring_2')['id'].count()
ser_spring_1_wave = pd.concat([ser_spring_1_1_wave, ser_spring_2_1_wave], axis=1)
ser_spring_1_wave = ser_spring_1_wave.sum(axis=1)
ser_spring_1_wave # серия, в которой показано, у какого количества студентов каждый курс указан первым приоритетом
# Out:
# Анализ данных в бизнесе                                   19.0
# Генеративные модели в машинном обучении                   16.0
# Дискретная оптимизация                                    31.0
# Дополнительные главы прикладной статистики                11.0
# Компьютерное зрение                                       29.0
# Компьютерные сети                                         43.0
# Конфликты и кооперация                                    19.0
# Машинное обучение 2                                       31.0
# Методы сжатия и передачи медиаданных                      22.0
# Обучение с подкреплением                                  61.0
# Проектирование и разработка высоконагруженных сервисов    47.0
# Промышленное программирование на языке Java               63.0
# Символьные вычисления                                      9.0
# Системы баз данных                                         8.0
# Численные методы                                           9.0
# dtype: float64

# %%
# определим курсы (sgood_courses), на которые желающих меньше, чем максимальное количество мест, и запишем потом всех желающих попасть на них сразу в первую волну
all_spring_courses_1_wave = list(ser_spring_1_wave.index)
special_courses = ['Анализ данных в бизнесе', 'Обучение с подкреплением']
sgood_courses = []
for course in all_spring_courses_1_wave:
  if course in special_courses:
    if ser_spring_1_wave[course] <= 60:
      sgood_courses.append(course)
  else:
    if ser_spring_1_wave[course] <= 30:
      sgood_courses.append(course)
sgood_courses
# Out:
# ['Анализ данных в бизнесе',
#  'Генеративные модели в машинном обучении',
#  'Дополнительные главы прикладной статистики',
#  'Компьютерное зрение',
#  'Конфликты и кооперация',
#  'Методы сжатия и передачи медиаданных',
#  'Символьные вычисления',
#  'Системы баз данных',
#  'Численные методы']

# %%
# проведём 1 волну
for item in all_spring_courses_1_wave:
  if item in sgood_courses:
    df.loc[(df['spring_1'] == item) & (df['course1'] == '-') & (df['num_spring_courses'] == 1.0), 'course1'] = item
    df.loc[((df['spring_1'] == item) | (df['spring_2'] == item)) & (df['num_spring_courses'] == 2.0) & (df['course1'] == '-'), 'course1'] = item
    df.loc[((df['spring_1'] == item) | (df['spring_2'] == item)) & (df['num_spring_courses'] == 2.0) & (df['course1'] != '-') & (df['course1'] != item) & (df['course2'] == '-'), 'course2'] = item
  else:
    if item in special_courses:
      massive = list(df.loc[(df['spring_1'] == item) | ((df['spring_2'] == item) & (df['num_spring_courses'] == 2.0) & (df['spring_2'] != df['spring_1']))].index)
      count = 0
      for i in range(len(massive)):
        if count < 60:
          if df.loc[massive[i], 'course1'] == '-':
            df.loc[massive[i], 'course1'] = item
            count += 1
          elif df.loc[massive[i], 'course1'] != item and df.loc[massive[i], 'course2'] == '-' and df.loc[massive[i], 'num_spring_courses'] == 2.0:
            df.loc[massive[i], 'course2'] = item
            count += 1
        else:
          break
    else:
      massive = list(df.loc[(df['spring_1'] == item) | ((df['spring_2'] == item) & (df['num_spring_courses'] == 2.0) & (df['spring_2'] != df['spring_1']))].index)
      count = 0
      for i in range(len(massive)):
        if count < 30:
          if df.loc[massive[i], 'course1'] == '-':
            df.loc[massive[i], 'course1'] = item
            count += 1
          elif df.loc[massive[i], 'course1'] != item and df.loc[massive[i], 'course2'] == '-' and df.loc[massive[i], 'num_spring_courses'] == 2.0:
            df.loc[massive[i], 'course2'] = item
            count += 1
        else:
          break
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
sser_1_wave_1_course_total = df.groupby('course1')['id'].count()
sser_1_wave_2_course_total = df.groupby('course2')['id'].count()
sser_1_wave_total = pd.concat([sser_1_wave_1_course_total, sser_1_wave_2_course_total], axis=1)
sser_1_wave_total = sser_1_wave_total.sum(axis=1)
sser_1_wave_total.drop(labels=['-'], inplace=True)
sser_1_wave_total_enrolled = sser_1_wave_total.copy()
sser_1_wave_total_enrolled # серия, которая показывает, сколько студентов на какой курс уже зачислены
# Out:
# Анализ данных в бизнесе                                   19.0
# Генеративные модели в машинном обучении                   16.0
# Дискретная оптимизация                                    30.0
# Дополнительные главы прикладной статистики                11.0
# Компьютерное зрение                                       29.0
# Компьютерные сети                                         30.0
# Конфликты и кооперация                                    19.0
# Машинное обучение 2                                       30.0
# Методы сжатия и передачи медиаданных                      22.0
# Обучение с подкреплением                                  60.0
# Проектирование и разработка высоконагруженных сервисов    30.0
# Промышленное программирование на языке Java               30.0
# Символьные вычисления                                      9.0
# Системы баз данных                                         8.0
# Численные методы                                           9.0
# dtype: float64

# %%
for item in all_spring_courses_1_wave:
  if item in special_courses:
    sser_1_wave_total[item] = 60 - sser_1_wave_total[item]
  else:
    sser_1_wave_total[item] = 30 - sser_1_wave_total[item]
sser_1_wave_total # показывает, сколько мест на курсах 1 волны осталось после 1 волны
# Out:
# Анализ данных в бизнесе                                   41.0
# Генеративные модели в машинном обучении                   14.0
# Дискретная оптимизация                                     0.0
# Дополнительные главы прикладной статистики                19.0
# Компьютерное зрение                                        1.0
# Компьютерные сети                                          0.0
# Конфликты и кооперация                                    11.0
# Машинное обучение 2                                        0.0
# Методы сжатия и передачи медиаданных                       8.0
# Обучение с подкреплением                                   0.0
# Проектирование и разработка высоконагруженных сервисов     0.0
# Промышленное программирование на языке Java                0.0
# Символьные вычисления                                     21.0
# Системы баз данных                                        22.0
# Численные методы                                          21.0
# dtype: float64

# %%
df_2s = df[(df['course1'] == '-') | ((df['num_spring_courses'] == 2.0) & (df['course2'] == '-'))]
df_2s.loc[:, 'num_courses_already_enrolled'] = 0
df_2s.loc[df_2s['course1'] != '-', 'num_courses_already_enrolled'] = 1
df_2s
# Out:
# <ipython-input-200-c15604d43e0e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2s.loc[:, 'num_courses_already_enrolled'] = 0
#                   timestamp                                id  rating  \
# 239 2020-05-14 23:33:21.310  e0fceae1e285f737630bb6123a1bd85d    1203
# 295 2020-05-18 18:27:32.822  7fcf56aae6836855a689000a50e80360    1145
# 125 2020-05-18 20:57:09.583  42df9e301b39e4295fe849aa2abdfc7c     613
# 25  2020-05-15 22:58:10.827  d82c2df25b8b36cd655077b4a885e1f7     612
# 193 2020-05-18 23:38:11.238  f941beb89ecc5c59076bcfa79691116c     610
# ..                      ...                               ...     ...
# 110 2020-05-18 19:36:51.479  f5d9f99cb876ca0888d18b6e444fa1b1     516
# ...

# %%
# проведём 2 волну, в ней будут участвовать из spring_2 с num_spring_courses = 1.0 и из spring_3 с num_spring_courses = 2.0
sser_spring_2_2_wave = df_2s[df_2s['num_spring_courses'] == 1.0].groupby('spring_2')['id'].count()
sser_spring_3_2_wave = df_2s[(df_2s['num_spring_courses'] == 2.0) & (df_2s['spring_3'] != df_2s['spring_2'])].groupby('spring_3')['id'].count()
sser_spring_2_wave = pd.concat([sser_spring_2_2_wave, sser_spring_3_2_wave], axis=1)
sser_spring_2_wave = sser_spring_2_wave.sum(axis=1)
sser_spring_2_wave # серия, в которой показано, у какого количества студентов каждый курс указан вторым приоритетом
# Out:
# Анализ данных в бизнесе                         9.0
# Дискретная оптимизация                          3.0
# Дополнительные главы прикладной статистики      3.0
# Компьютерное зрение                             5.0
# Компьютерные сети                              13.0
# Конфликты и кооперация                          1.0
# Машинное обучение 2                             6.0
# Методы сжатия и передачи медиаданных            6.0
# Промышленное программирование на языке Java     9.0
# Системы баз данных                              3.0
# Численные методы                                5.0
# Генеративные модели в машинном обучении         2.0
# Обучение с подкреплением                        1.0
# Символьные вычисления                           1.0
# dtype: float64

# %%
all_spring_courses_2_wave = list(sser_spring_2_wave.index)
# определим курсы (sgood_courses2), на которые желающих меньше, чем максимальное количество мест, и запишем потом всех желающих попасть на них сразу во вторую волну
sgood_courses2 = []
for course in all_spring_courses_2_wave:
  if course in all_spring_courses_1_wave:
    if sser_spring_2_wave[course] <= sser_1_wave_total[course]:
      sgood_courses2.append(course)
  else:
    if course in special_courses:
      if sser_spring_2_wave[course] <= 60:
        sgood_courses2.append(course)
    else:
      if sser_spring_2_wave[course] <= 30:
        sgood_courses2.append(course)
sgood_courses2
# Out:
# ['Анализ данных в бизнесе',
#  'Дополнительные главы прикладной статистики',
#  'Конфликты и кооперация',
#  'Методы сжатия и передачи медиаданных',
#  'Системы баз данных',
#  'Численные методы',
#  'Генеративные модели в машинном обучении',
#  'Символьные вычисления']

# %%
for item in all_spring_courses_2_wave:
  if item in all_spring_courses_1_wave:
    if item in sgood_courses2:
      df_2s.loc[(df_2s['spring_2'] == item) & (df_2s['course1'] == '-') & (df_2s['num_spring_courses'] == 1.0), 'course1'] = item
      df_2s.loc[(df_2s['spring_3'] == item) & (df_2s['num_spring_courses'] == 2.0) & (df_2s['course1'] == '-'), 'course1'] = item
      df_2s.loc[(df_2s['spring_3'] == item) & (df_2s['num_spring_courses'] == 2.0) & (df_2s['course1'] != '-') & (df_2s['course1'] != item) & (df_2s['course2'] == '-'), 'course2'] = item
    else:
      massive = list(df_2s.loc[((df_2s['spring_2'] == item) & (df_2s['num_spring_courses'] == 1.0)) | ((df_2s['spring_3'] == item) & (df_2s['num_spring_courses'] == 2.0))].index)
      count = 0
      for i in range(len(massive)):
        if count < sser_1_wave_total[item]:
          if df_2s.loc[massive[i], 'course1'] == '-':
            df_2s.loc[massive[i], 'course1'] = item
            count += 1
          elif df_2s.loc[massive[i], 'course1'] != item and df_2s.loc[massive[i], 'course2'] == '-' and df_2s.loc[massive[i], 'num_spring_courses'] == 2.0:
            df_2s.loc[massive[i], 'course2'] = item
            count += 1
        else:
          break
  else:
    if item in sgood_courses2:
      df_2s.loc[(df_2s['spring_2'] == item) & (df_2s['course1'] == '-') & (df_2s['num_spring_courses'] == 1.0), 'course1'] = item
      df_2s.loc[(df_2s['spring_3'] == item) & (df_2s['num_spring_courses'] == 2.0) & (df_2s['course1'] == '-'), 'course1'] = item
      df_2s.loc[(df_2s['spring_3'] == item) & (df_2s['num_spring_courses'] == 2.0) & (df_2s['course1'] != '-') & (df_2s['course1'] != item) & (df_2s['course2'] == '-'), 'course2'] = item
    else:
      if item in special_courses:
        massive = list(df_2s.loc[((df_2s['spring_2'] == item) & (df_2s['num_spring_courses'] == 1.0)) | ((df_2s['spring_3'] == item) & (df_2s['num_spring_courses'] == 2.0))].index)
        count = 0
        for i in range(len(massive)):
          if count < 60:
            if df_2s.loc[massive[i], 'course1'] == '-':
              df_2s.loc[massive[i], 'course1'] = item
              count += 1
            elif df_2s.loc[massive[i], 'course1'] != item and df_2s.loc[massive[i], 'course2'] == '-' and df_2s.loc[massive[i], 'num_spring_courses'] == 2.0:
              df_2s.loc[massive[i], 'course2'] = item
              count += 1
          else:
            break
      else:
        massive = list(df_2s.loc[((df_2s['spring_2'] == item) & (df_2s['num_spring_courses'] == 1.0)) | ((df_2s['spring_3'] == item) & (df_2s['num_spring_courses'] == 2.0))].index)
        count = 0
        for i in range(len(massive)):
          if count < 30:
            if df_2s.loc[massive[i], 'course1'] == '-':
              df_2s.loc[massive[i], 'course1'] = item
              count += 1
            elif df_2s.loc[massive[i], 'course1'] != item and df_2s.loc[massive[i], 'course2'] == '-' and df_2s.loc[massive[i], 'num_fall_courses'] == 2.0:
              df_2s.loc[massive[i], 'course2'] = item
              count += 1
          else:
            break
df_2s
# Out:
#                   timestamp                                id  rating  \
# 239 2020-05-14 23:33:21.310  e0fceae1e285f737630bb6123a1bd85d    1203
# 295 2020-05-18 18:27:32.822  7fcf56aae6836855a689000a50e80360    1145
# 125 2020-05-18 20:57:09.583  42df9e301b39e4295fe849aa2abdfc7c     613
# 25  2020-05-15 22:58:10.827  d82c2df25b8b36cd655077b4a885e1f7     612
# 193 2020-05-18 23:38:11.238  f941beb89ecc5c59076bcfa79691116c     610
# ..                      ...                               ...     ...
# 110 2020-05-18 19:36:51.479  f5d9f99cb876ca0888d18b6e444fa1b1     516
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
#
#      18_group  is_mi                                           fall_1  \
# ...

# %%
sser_2_wave_1_course_total = df_2s[df_2s['num_courses_already_enrolled'] == 0].groupby('course1')['id'].count()

sser_2_wave_2_course_total = df_2s[df_2s['num_courses_already_enrolled'] == 1].groupby('course2')['id'].count()
sser_2_wave_total = pd.concat([sser_2_wave_1_course_total, sser_2_wave_2_course_total], axis=1)
sser_2_wave_total = sser_2_wave_total.sum(axis=1)

sser_2_wave_total = pd.concat([sser_1_wave_total_enrolled, sser_2_wave_total], axis=1)

sser_2_wave_total = sser_2_wave_total.sum(axis=1)
sser_2_wave_total.drop(labels=['-'], inplace=True)
sser_2_wave_total_enrolled = sser_2_wave_total.copy()
sser_2_wave_total_enrolled # серия, которая показывает, сколько студентов на какой курс уже зачислены суммарно в 1 и во 2 волну
# Out:
# Анализ данных в бизнесе                                   28.0
# Генеративные модели в машинном обучении                   18.0
# Дискретная оптимизация                                    30.0
# Дополнительные главы прикладной статистики                14.0
# Компьютерное зрение                                       30.0
# Компьютерные сети                                         30.0
# Конфликты и кооперация                                    20.0
# Машинное обучение 2                                       30.0
# Методы сжатия и передачи медиаданных                      28.0
# Обучение с подкреплением                                  60.0
# Проектирование и разработка высоконагруженных сервисов    30.0
# Промышленное программирование на языке Java               30.0
# Символьные вычисления                                     10.0
# Системы баз данных                                        11.0
# Численные методы                                          14.0
# dtype: float64

# %%
for item in all_spring_courses_1_wave:
  if item in all_spring_courses_2_wave:
    if item in special_courses:
      sser_2_wave_total[item] = 60 - sser_2_wave_total[item]
    else:
      sser_2_wave_total[item] = 30 - sser_2_wave_total[item]
  else:
    if item in special_courses:
      sser_2_wave_total[item] = 60 - sser_2_wave_total[item]
    else:
      sser_2_wave_total[item] = 30 - sser_2_wave_total[item]
sser_2_wave_total # показывает, сколько мест на курсах 2 волны осталось после 2 волны
# Out:
# Анализ данных в бизнесе                                   32.0
# Генеративные модели в машинном обучении                   12.0
# Дискретная оптимизация                                     0.0
# Дополнительные главы прикладной статистики                16.0
# Компьютерное зрение                                        0.0
# Компьютерные сети                                          0.0
# Конфликты и кооперация                                    10.0
# Машинное обучение 2                                        0.0
# Методы сжатия и передачи медиаданных                       2.0
# Обучение с подкреплением                                   0.0
# Проектирование и разработка высоконагруженных сервисов     0.0
# Промышленное программирование на языке Java                0.0
# Символьные вычисления                                     20.0
# Системы баз данных                                        19.0
# Численные методы                                          16.0
# dtype: float64

# %%
# перенесём записи в df
for ind in list(df_2s.index):
  df.loc[ind, 'course1'] = df_2s.loc[ind, 'course1']
  df.loc[ind, 'course2'] = df_2s.loc[ind, 'course2']
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
# проведём 3 волну, в ней будут участвовать из spring_3 с num_spring_courses = 1.0
df_3s = df[(df['course1'] == '-') & (df['num_spring_courses'] == 1.0)]
sser_spring_3_wave = df_3s.groupby('spring_3')['id'].count()
sser_spring_3_wave # серия, в которой показано, у какого количества студентов каждый курс указан третьим приоритетом
# Out:
# spring_3
# Анализ данных в бизнесе                                   4
# Дискретная оптимизация                                    8
# Дополнительные главы прикладной статистики                1
# Компьютерные сети                                         7
# Машинное обучение 2                                       2
# Проектирование и разработка высоконагруженных сервисов    1
# Промышленное программирование на языке Java               1
# Системы баз данных                                        6
# Численные методы                                          2
# Name: id, dtype: int64

# %%
all_spring_courses_3_wave = list(sser_spring_3_wave.index)
# определим курсы (sgood_courses3), на которые желающих меньше, чем максимальное количество мест, и запишем потом всех желающих попасть на них сразу в третью волну
sgood_courses3 = []
for course in all_spring_courses_3_wave:
  if course in all_spring_courses_2_wave:
    if sser_spring_3_wave[course] <= sser_2_wave_total[course]:
      sgood_courses3.append(course)
  elif course in all_spring_courses_1_wave:
    if sser_spring_3_wave[course] <= sser_1_wave_total[course]:
      sgood_courses3.append(course)
  else:
    if course in special_courses:
      if sser_spring_3_wave[course] <= 60:
        sgood_courses3.append(course)
    else:
      if sser_spring_3_wave[course] <= 30:
        sgood_courses3.append(course)
sgood_courses3
# Out:
# ['Анализ данных в бизнесе',
#  'Дополнительные главы прикладной статистики',
#  'Системы баз данных',
#  'Численные методы']

# %%
for item in all_spring_courses_3_wave:
  if item in all_spring_courses_2_wave:
    if item in sgood_courses3:
      df_3s.loc[(df_3s['spring_3'] == item) & (df_3s['course1'] == '-'), 'course1'] = item
    else:
      massive = list(df_3s.loc[(df_3s['spring_3'] == item) & (df_3s['course1'] == '-')].index)
      count = 0
      for i in range(len(massive)):
        if count < sser_2_wave_total[item]:
          df_3s.loc[massive[i], 'course1'] = item
          count += 1
        else:
          break
  elif item in all_spring_courses_1_wave:
    if item in sgood_courses3:
      df_3s.loc[(df_3s['spring_3'] == item) & (df_3s['course1'] == '-'), 'course1'] = item
    else:
      massive = list(df_3s.loc[(df_3s['spring_3'] == item) & (df_3s['course1'] == '-')].index)
      count = 0
      for i in range(len(massive)):
        if count < sser_1_wave_total[item]:
          df_3s.loc[massive[i], 'course1'] = item
          count += 1
        else:
          break
  else:
    if item in sgood_courses3:
      df_3s.loc[(df_3s['spring_3'] == item) & (df_3s['course1'] == '-'), 'course1'] = item
    else:
      if item in special_courses:
        massive = list(df_3s.loc[(df_3s['spring_3'] == item) & (df_3s['course1'] == '-')].index)
        count = 0
        for i in range(len(massive)):
          if count < 60:
            if df_3s.loc[massive[i], 'course1'] == '-':
              df_3s.loc[massive[i], 'course1'] = item
              count += 1
          else:
            break
      else:
        massive = list(df_3s.loc[(df_3s['spring_3'] == item) & (df_3s['course1'] == '-')].index)
        count = 0
        for i in range(len(massive)):
          if count < 30:
            if df_3s.loc[massive[i], 'course1'] == '-':
              df_3s.loc[massive[i], 'course1'] = item
              count += 1
          else:
            break
df_3s
# Out:
#                   timestamp                                id  rating  \
# 125 2020-05-18 20:57:09.583  42df9e301b39e4295fe849aa2abdfc7c     613
# 25  2020-05-15 22:58:10.827  d82c2df25b8b36cd655077b4a885e1f7     612
# 172 2020-05-18 22:35:46.073  ddea5295ac96e74f05982e47c7ab4ff4     607
# 132 2020-05-18 21:15:01.777  f0db08ec702a03450390efdca4166cc2     603
# 149 2020-05-18 21:47:05.660  9fa4bc4eb50e574e88b670a86781860b     600
# 178 2020-05-18 22:56:27.522  6388c7920a7d454d2db81430f1f231c4     599
# 108 2020-05-18 19:35:49.258  1c1623a037bd523d687245e6060e6c5b     595
# 168 2020-05-18 22:20:36.242  c7544f6c00a5164efdef675410d62e94     586
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0     584
# 206 2020-05-18 23:59:29.314  f7f123322f77fd451a30ed4979c323fc     578
# 126 2020-05-18 21:02:28.759  5c49473012411a1eee72f8ea63767adf     573
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ...

# %%
sser_3_wave_total = df_3s.groupby('course1')['id'].count()
sser_3_wave_total.drop(labels=['-'], inplace=True)

sser_3_wave_total = pd.concat([sser_2_wave_total_enrolled, sser_3_wave_total], axis=1)

sser_3_wave_total = sser_3_wave_total.sum(axis=1)
sser_3_wave_total_enrolled = sser_3_wave_total.copy()
sser_3_wave_total_enrolled # серия, которая показывает, сколько студентов на какой курс зачислены после всех трёх волн
# Out:
# Анализ данных в бизнесе                                   32.0
# Генеративные модели в машинном обучении                   18.0
# Дискретная оптимизация                                    30.0
# Дополнительные главы прикладной статистики                15.0
# Компьютерное зрение                                       30.0
# Компьютерные сети                                         30.0
# Конфликты и кооперация                                    20.0
# Машинное обучение 2                                       30.0
# Методы сжатия и передачи медиаданных                      28.0
# Обучение с подкреплением                                  60.0
# Проектирование и разработка высоконагруженных сервисов    30.0
# Промышленное программирование на языке Java               30.0
# Символьные вычисления                                     10.0
# Системы баз данных                                        17.0
# Численные методы                                          16.0
# dtype: float64

# %%
# перенесём записи 3 волны в df
for ind in list(df_3s.index):
  df.loc[ind, 'course1'] = df_3s.loc[ind, 'course1']
  df.loc[ind, 'course2'] = df_3s.loc[ind, 'course2']
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %%
df.loc[(df['num_spring_courses'] == 1.0) & (df['course1'] == '-'), 'course1'] = '???'
df.loc[(df['num_spring_courses'] == 2.0) & (df['course1'] == '-'), 'course1'] = '???'
df.loc[(df['num_spring_courses'] == 2.0) & (df['course2'] == '-'), 'course2'] = '???'
df_res_spring = df[['id', 'course1', 'course2']]
df_res_spring = df_res_spring.rename(columns={'id' : 'ID'})
df_res_spring
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1           course2
# 80                              Дискретная оптимизация                 -
# 231                              Символьные вычисления  Численные методы
# 91                              Дискретная оптимизация                 -
# 273  Проектирование и разработка высоконагруженных ...                 -
# 19          Дополнительные главы прикладной статистики                 -
# ...

# %%
df_res_spring.to_csv('res_spring.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# никнейм: nsnazarov@edu.hse.ru
#
# ссылка на успешную посылку: https://contest.yandex.ru/contest/68637/run-report/120310615/
#
# ID успешной посылки: 120310615

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %%
from PIL import Image

image_path = '/content/exhausted_kitten.jpg'
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')
plt.show()
